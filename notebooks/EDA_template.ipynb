# %% [markdown]
# Set-ups

# %%
# clone your repo into Colab
# !git clone https://github.com/armitaswan/movie-recommender-ml-project.git

# go into the folder
# %cd movie-recommender-ml-project

# now install requirements
# !pip install -r requirements.txt
# Out:
# Cloning into 'movie-recommender-ml-project'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 35 (delta 0), reused 32 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 9.28 KiB | 9.28 MiB/s, done.
# /content/movie-recommender-ml-project
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 5.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.4/316.4 kB 13.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# # EDA & Data Prep\nExplore ratings distribution, sparsity, and temporal dynamics.

# %%
import pandas as pd\nfrom src.config import PROC_DIR\nmovies = pd.read_parquet(PROC_DIR / 'movies.parquet')\nratings = pd.read_parquet(PROC_DIR / 'ratings.parquet')\nmovies.shape, ratings.shape

# %%
import matplotlib.pyplot as plt\nratings['rating'].hist(bins=10)\nplt.title('Rating Distribution')\nplt.xlabel('Rating')\nplt.ylabel('Count')\nplt.show()
